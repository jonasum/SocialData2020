# %%
import pandas as pd

{
    "tags": [
        "hide_output",
    ]
}
# Out:
# {'tags': ['hide_output']}

# %%
df = pd.read_csv("appdata1.csv")

# %%
df['day'] = df.time.str[0:2]
df['month'] = df.time.str[3:5]
df['year'] = df.time.str[6:10]
df['hour'] = df.time.str[11:13]
df['minute'] = df.time.str[14:16]
df['second'] = df.time.str[17:19]

# %%
df.plot()
